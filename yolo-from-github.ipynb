# %%
# !pwd
# Out:
# /content

# %%
# !git clone https://github.com/xslittlegrass/CarND-Vehicle-Detection.git
# Out:
# Cloning into 'CarND-Vehicle-Detection'...
# remote: Enumerating objects: 64, done.
# remote: Total 64 (delta 0), reused 0 (delta 0), pack-reused 64
# Unpacking objects: 100% (64/64), done.

# %%
# !cd CarND-Vehicle-Detection/

# %%
# !cd CarND-Vehicle-Detection/

# %%
cd CarND-Vehicle-Detection/
# Out:
# /content/CarND-Vehicle-Detection

# %%
# !ls
# Out:
#  output_images	     README.md	   utils
#  project_video.mp4   test_images  'vehicle detection.ipynb'

# %%
# !ipython nbconvert --to python vehicle\ detection.ipynb
# Out:
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook vehicle detection.ipynb to python
# [NbConvertApp] Writing 4186 bytes to vehicle detection.py

# %% [markdown]
# # New Section

# %%
# !pwd
# Out:
# /content

# %%
# !pwd
# Out:
# /content/CarND-Vehicle-Detection

# %%
# !mv vehicle\ detection.ipynb vehicle_detection.ipynb

# %%
# !ls
# Out:
#  output_images	     test_images	      'vehicle detection.py'
#  project_video.mp4   utils
#  README.md	     vehicle_detection.ipynb

# %%
# !ipython nbconvert --to python vehicle_detection.ipynb
# Out:
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook vehicle_detection.ipynb to python
# [NbConvertApp] Writing 4186 bytes to vehicle_detection.py

# %%
# !ipython vehicle_detection.py
# Out:
# [TerminalIPythonApp] WARNING | GUI event loop or pylab initialization failed
#
# UnknownBackendTraceback (most recent call last)
# /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.pyc in enable_matplotlib(self, gui)
#    2953         # Now we must activate the gui pylab wants to use, and fix %run to take
#    2954         # plot updates into account
# -> 2955         self.enable_gui(gui)
#    2956         self.magics_manager.registry['ExecutionMagics'].default_runner = \
#    2957             pt.mpl_runner(self.safe_execfile)
#
# /usr/local/lib/python2.7/dist-packages/IPython/terminal/interactiveshell.pyc in enable_gui(self, gui)
#     512         if gui:
#     513             self.active_eventloop, self._inputhook =\
# --> 514                 get_inputhook_name_and_func(gui)
#     515         else:
#     516             self.active_eventloop = self._inputhook = None
#
# ...

# %%
# !jupyter notebook
# Out:
# |INFO|google.colab serverextension initialized.
# |INFO|Serving notebooks from local directory: /content/CarND-Vehicle-Detection
# |INFO|0 active kernels
# |INFO|The Jupyter Notebook is running at:
# |INFO|http://localhost:8888/
# |INFO|Use Control-C to stop this server and shut down all kernels (twice to skip confirmation).
